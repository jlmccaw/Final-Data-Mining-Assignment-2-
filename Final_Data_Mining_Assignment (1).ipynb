# %%
import seaborn as sns
import pandas as pd

# %%
marketingdata = pd.read_csv('Marketingdata2022.csv')

# %%
marketingdata.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
marketingdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
marketingdata['Country'].value_counts()
# Out:
# SP     1095
# SA      337
# CA      268
# AUS     160
# IND     148
# GER     120
# US      109
# ME        3
# Name: Country, dtype: int64

# %%
marketingdata.corr()
# Out:
#                            ID  Year_Birth   Kidhome  Teenhome   Recency  \
# ID                   1.000000    0.000028  0.002406 -0.002580 -0.046524
# Year_Birth           0.000028    1.000000  0.230176 -0.352111 -0.019871
# Kidhome              0.002406    0.230176  1.000000 -0.036133  0.008827
# Teenhome            -0.002580   -0.352111 -0.036133  1.000000  0.016198
# Recency             -0.046524   -0.019871  0.008827  0.016198  1.000000
# MntWines            -0.022878   -0.157773 -0.496297  0.004846  0.016064
# MntFruits            0.004600   -0.017917 -0.372581 -0.176764 -0.004306
# MntMeatProducts     -0.004437   -0.030872 -0.437129 -0.261160  0.023056
# MntFishProducts     -0.024475   -0.041625 -0.387644 -0.204187  0.001079
# MntSweetProducts    -0.007642   -0.018133 -0.370673 -0.162475  0.022670
# MntGoldProds        -0.013438   -0.061818 -0.349595 -0.021725  0.016693
# NumDealsPurchases   -0.037166   -0.060846  0.221798  0.387741 -0.001098
# ...

# %%
sns.heatmap(marketingdata.corr(), annot=True)

# %%
sns.heatmap(marketingdata.corr(), cmap="YlGnBu")

# %%
sns.scatterplot(x="NumWebPurchases", y = "NumDealsPurchases", data = marketingdata)

# %%
sns.lmplot(x = "NumDealsPurchases", y = "NumWebPurchases", data = marketingdata)

# %%
sns.scatterplot(x = "NumDealsPurchases", y = "NumWebPurchases", hue="Complain", data=marketingdata)

# %%
sns.lmplot(x = "NumDealsPurchases", y = "NumWebPurchases", hue="Complain", data=marketingdata)

# %%
sns.countplot(x='Response', data=marketingdata)

# %%
sns.countplot(x='Marital_Status', data=marketingdata)

# %%
sns.countplot(x='Education', data=marketingdata)

# %%
sns.countplot(x='Education', data=marketingdata, color = 'b')

# %%
Income_Education=marketingdata.groupby('Education')
Income_Education.mean()
# Out:
#                            ID   Year_Birth   Kidhome  Teenhome    Recency  \
# Education
# Bachelors_Degree  5652.523514  1969.635315  0.444543  0.494232  50.035492
# HighSchool        5547.910506  1973.167315  0.509728  0.342412  48.424125
# Master            5403.648649  1966.878378  0.454054  0.535135  47.586486
# PhD               5619.096708  1966.043210  0.401235  0.598765  48.483539
#
#                     MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Education
# Bachelors_Degree  284.268855  30.774623       179.488909        43.149956
# HighSchool        158.062257  25.206226       113.980545        41.089494
# Master            333.075676  21.654054       163.378378        32.100000
# PhD               404.495885  20.049383       168.602881        26.728395
#
#                   MntSweetProducts  ...  NumCatalogPurchases  \
# Education                           ...
# Bachelors_Degree         31.367347  ...             2.725821
# ...

# %%
sns.boxplot(x="Education", y = "MntWines", data = marketingdata)

# %%
sns.boxplot(x="Education", y = "MntWines", hue="Complain", data = marketingdata)

# %%
Top3_MntWines=marketingdata.nlargest(3,"MntWines")
Top3_MntWines
# Out:
#         ID  Year_Birth         Education                 Marital_Status  \
# 137    737        1949               PhD                        Married
# 639   3174        1959  Bachelors_Degree  Living_with_Significant_Other
# 1133  5536        1959  Bachelors_Degree  Living_with_Significant_Other
#
#           Income   Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  \
# 137   $80,360.00         0         0    3/3/2013       56      1493  ...
# 639   $87,771.00         0         1   5/22/2013       61      1492  ...
# 1133  $87,771.00         0         1   5/22/2013       61      1492  ...
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 137                   5                  2             0             1
# 639                   4                  6             0             1
# 1133                  4                  6             0             1
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country
# ...
